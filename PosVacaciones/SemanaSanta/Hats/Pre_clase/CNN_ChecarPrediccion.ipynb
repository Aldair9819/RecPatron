# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from PIL import Image
import subprocess
import face_recognition
from tensorflow.keras.models import load_model

# %%
# Especifica la ruta del archivo h5 de tu modelo
ruta_modelo_h5 = 'M_hats_0904_200E_Gray.h5'
#ruta_modelo_h5 = 'M_hats_0604_70.h5'

# Cargar el modelo
model = load_model(ruta_modelo_h5)

# Ahora el modelo está cargado y listo para ser utilizado
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 6
#       3 ruta_modelo_h5 = 'DB_Hats_Gray.h5'
#       5 # Cargar el modelo
# ----> 6 model = load_model(ruta_modelo_h5)
#       8 # Ahora el modelo está cargado y listo para ser utilizado
#
# File ~/.local/lib/python3.10/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/keras/src/saving/legacy/hdf5_format.py:197, in load_model_from_hdf5(filepath, custom_objects, compile)
#     195 model_config = f.attrs.get("model_config")
#     196 if model_config is None:
# --> 197     raise ValueError(
#     198         f"No model config found in the file at {filepath}."
#     199     )
#     200 if hasattr(model_config, "decode"):
#     201     model_config = model_config.decode("utf-8")
#
# ValueError: No model config found in the file at <tensorflow.python.platform.gfile.GFile object at 0x7f44802e3250>.

# %%
clases = ""
with open('clases.txt', 'r') as f:
    clases = f.readlines()
clases = [c.strip() for c in clases]

# %%
#"""""""""
#A color
imagen = face_recognition.load_image_file("7.jpg")
                    
# Redimensionar la imagen a 150x150
imagen_redimensionada = np.array(Image.fromarray(imagen).resize((224, 224)))
X_test = np.array([imagen_redimensionada])
X_test = X_test.astype('float32') / 255
#"""""""""

# %%
#A grises
#"""""""""
imagen = Image.open("7.jpg").convert('L')
                    
# Redimensionar la imagen a 150x150
imagen_redimensionada = np.array(imagen.resize((224, 224)))
X_test = np.array([imagen_redimensionada])
X_test = X_test.astype('float32') / 255
#"""""""""
# Out:
# '\nimagen = Image.open("7.jpg").convert(\'L\')\n                    \n# Redimensionar la imagen a 150x150\nimagen_redimensionada = np.array(imagen.resize((224, 224)))\nX_test = np.array([imagen_redimensionada])\nX_test = X_test.astype(\'float32\') / 255\n'

# %%
import matplotlib.pyplot as plt
# Cargar las clases desde el archivo


# Realizar la predicción
prediccion = model.predict(X_test)

# Obtener el índice de la clase predicha
indice_predicho = np.argmax(prediccion)

# Obtener la etiqueta predicha
etiqueta_predicha = clases[indice_predicho]

# Imprimir la etiqueta predicha
print("La etiqueta predicha es:", etiqueta_predicha)


imagen_prueba = imagen_redimensionada
# Suponiendo que 'imagen' es tu array numpy que contiene la imagen
plt.imshow(imagen_prueba)
plt.axis('off')  # Desactivar los ejes si no son necesarios
plt.show()
# Out:
# 1/1 [==============================] - 0s 15ms/step
# La etiqueta predicha es: BERET
